# %% [markdown]
# # **Python Terminology**
#
# **Object:**
#
# - An object is a specific **instance of a data type** or class.
#
# - Everything in Python i.e.**numbers, strings, lists, dictionaries, functions**, and even classes themselves—are objects.
#
#
# **Variable:**
#
# - A **variable is just a name** that refers to an object.
#
# - It acts as a **label or reference** to stored data.
#
# - **Variable doesn't directly hold the data** itself.
#
# - **x = 10** : **'x' is a variable** that refers to the **object 10.**
#
# **Object - Variable Analogy:**
#
# - Think of an **object as a house** and a **variable as a street address** pointing to that house.
#
# - The **address itself isn’t the house**, it just helps us find it.
#
# **Identifier:**
#
# - An identifier is the **name used to identify variables, functions, classes, or modules** in Python.
#
# - It is essentially the **label you assign when declaring a variable, function, or any other entity**.
#
# **Literal:**
#
# - a literal is a **fixed value assigned directly to a variable** or used in an expression.
#
# - Literals represent **constant values and do not change during execution**.

# %% [markdown]
# # **Creating Variables in Python**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Step 1: Choose a Variable Name:**
#
# - Pick a meaningful name that follows Python's naming rules.
#
# - The name should be easy to understand and should represent the data it holds.
#
# - Python has specific rules for naming variables:
#
#
# ### **Step 2: Assign a Value:**
#
# - Once you have chosen a variable name, assign a value to it using the `=` operator.
#
# - This step determines what kind of data the variable will hold—such as text, numbers, or Boolean values.
#
# - Since Python is **dynamically typed**, variables can store different types of values without explicit type declarations.

# %% [markdown]
# # **Let's Create Python Variables**
#
# - Single Value Assignment
#
# - Multiple Value Assignment

# %%
# create a variable "x" to store an integer 99
x=999
print(x)
# Out:
# 999

# %%
# create a variable "myname" to store your name
myname="upendra"
print(myname)
# Out:
# upendra

# %%
# Single value Assignment
x=10
y=20
z=30
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
# ex -2
name1="hyderabad"
name2="pune"
name3="bangalore"
print(name1)
print(name2)
print(name3)
# Out:
# hyderabad
# pune
# bangalore

# %%
# Multiple value assignment
x,y,z=11,22,33
print(x)
print(y)
print(z)
# Out:
# 11
# 22
# 33

# %%
# printing multiple variables with a single print function
print(x,y,z)
# Out:
# 11 22 33

# %%
# ex -2: multiple value assignment
name,city,pin="upendra","hyd",500001
print(name,city,pin)
# Out:
# upendra hyd 500001

# %%
# Fail cases of multiple value assignment
x,y,z=9,99
print(x,y,z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-daa74159a3c0> in <cell line: 0>()
#       1 # Fail cases of multiple value assignment
# ----> 2 x,y,z=9,99
#       3 print(x,y,z)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
x,y=9,99,999
print(x,y,z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1734807124.py in <cell line: 0>()
# ----> 1 x,y=9,99,999
#       2 print(x,y,z)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # **Note:**
#
# - In above, we created 3 variables, but we passed only two values. Hence, it is generated an error (Value Error)

# %%
# Another example
x1,x2=100,200,300
print(x1)
print(x2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-5d06a4dbe04f> in <cell line: 0>()
# ----> 1 x1,x2=100,200,300
#       2 print(x1)
#       3 print(x2)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# **Note:**
#
# - In above code, there are two variables, but three values are passed. Hence, it resulted in an error.
#
# - In multiple value assignment, make sure that always **number of variables should be equal to number of values.**

# %% [markdown]
# **Rules to Choose Variable Name:**
#
# Python has specific rules for naming variables to ensure clarity and consistency in code. Here are the key rules:
#
# 1. **Start with a Letter or Underscore**:
#
# - Variable names must begin with a letter (`A-Z`, `a-z`) or an underscore (`_`). They cannot start with a number.
#
# - Therei no limit to the length of variable name.
#
# 2. **Don't statrt with a Number**:
#
# - Variable name should not start with a digit (0 - 9).
#
# - It can statrt either by '_' or by a character.
#
# 3. **Avoid Python Keywords**:
#
# - Variable names cannot be Python **reserved words** like `if`, `while`, `class`, `True`, `False`, etc.
#
# 4. **Case Sensitivity**:
#
# - Python treats variable names as **case-sensitive**.
# - meaning `myVar`, `MyVar`, and `MYVAR` are considered different variables.
#
# 5. **No Spaces or Special Characters**:
#
# - Variable names cannot contain spaces or symbols like `-`, `+`, `*`, or `&`.
#
#
# While Python allows single-letter variables (`x`, `y`), it's best to use descriptive names (`student_name`, `total_price`) for better readability.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Let us try all the above rules.
# no limit for a length of variable name

x=10
print(x)
# Out:
# 10

# %%
num=10
print(num)
# Out:
# 10

# %%
number=10
print(number)
# Out:
# 10

# %%
mynumber=10
print(mynumber)
# Out:
# 10

# %%
firstnumber=10
print(firstnumber)
# Out:
# 10

# %%
# 2: number (digits) are allowed in variable name
#    but variable name should not start with digit

# %%
x1=10
x2=20
x3=30
print(x1,x2,x3)
# Out:
# 10 20 30

# %%
# fail case example
2x=99
print(2x)
# Out:
#   File "<ipython-input-14-961dbc77f0ad>", line 1
#     2x=99
#     ^
# SyntaxError: invalid decimal literal

# %%
# spaces are not allowed in a variable name
my number=10
print(my number)
# Out:
#   File "<ipython-input-15-32d81d8a1cf0>", line 2
#     my number=10
#        ^
# SyntaxError: invalid syntax

# %%
my_number=10
print(my_number)
# Out:
# 10

# %%
# python variable are case sensitive
apple_price=100
print(Apple_price)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-878acf3bfd13> in <cell line: 0>()
#       1 # python variable are case sensitive
#       2 apple_price=100
# ----> 3 print(Apple_price)
#
# NameError: name 'Apple_price' is not defined

# %%
print(apple_price)
# Out:
# 100

# %%
# another example
a=10
print(A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-06260717a09b> in <cell line: 0>()
#       1 # another example
#       2 a=10
# ----> 3 print(A)
#
# NameError: name 'A' is not defined

# %%
# don't use reserved words (keywords)
# don;t use words like True, False, if, else

# %% [markdown]
# **Fundamental Properties of Python Variables:**
#
# **Identity of a variable:**
#
# - In Python, the identity of a variable refers to its **unique memory address** where the object is stored.
#
# - Every object in Python has a **distinct identity**, which can be checked using the **id()** function.
#
# **Type of a variable:**
#
# - It refers the **data type** of the data of a variable.
#
# - The data type of a varaible can be checked using **type()** function.
#
# - We can also use **isinstance()** function to **check if a variable belongs to a specific type**.
#
# - **Example:** x = 10 ----> **print(isinstance(x, int))**  # Output: True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Let us try id() and type() functions.
x=10
print(x)
print(id(x))
# Out:
# 10
# 10751144

# %%
name="upendra"
print(name)
print(id(name))
# Out:
# upendra
# 136028163528368

# %%
x,y,z=10,10.99,"hyd"
print(x)
print(id(x))
print(y)
print(id(y))
print(z)
print(id(z))
# Out:
# 10
# 10751144
# 10.99
# 136028712283792
# hyd
# 136028721851056

# %%
# identity of two variable storing same data
x=10
y=x
print(x)
print(y)

print(id(x))
print(id(y))
# Out:
# 10
# 10
# 11654664
# 11654664

# %%
# let us verify data type of variables
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'int'>

# %%
print(id(x))
print(id(y))
# Out:
# 10751144
# 10751144

# %%
# another example
name1="hyd"
name2=name1
print(id(name1))
print(id(name2))
# Out:
# 136028721851056
# 136028721851056

# %%
print(type(name1))
print(type(name2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
# one more example
x1=99.99
x2=x1
x3=x2
print(id(x1),id(x2),id(x3))
# Out:
# 136028712284112 136028712284112 136028712284112

# %%
print(type(x1))
print(type(x2))
print(type(x3))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
# another example
z=2+3j
print(z)
print(type(z))
# Out:
# (2+3j)
# <class 'complex'>

# %%
number=2e3
print(number)
print(type(number))
# Out:
# 2000.0
# <class 'float'>

# %%
n2=3E4
print(n2)
print(type(n2))
# Out:
# 30000.0
# <class 'float'>

# %% [markdown]
# # **Data Types in Python**
#
# Python has several built-in **data types** that help store and manipulate different kinds of values.
#
# **1. Numeric Types:**
#
# - **int**: Whole numbers (10, -5)
# - **float**: Decimal numbers (3.14, -0.5)
# - **complex**: Numbers with real and imaginary parts (2 + 3j)
#
# **2. Text Type:**
#
# - **str**: Represents text ("Hello, Python!")
#
# **3. Boolean Type:**
#
# - **bool**: Represents **True** or **False**
#
# **4. Sequence Types:**
#
# - **list**: Ordered, mutable collection ([1, 2, 3])
#
# - **tuple**: Ordered, immutable collection ((4, 5, 6))
#
# **5. Mapping Type:**
#
# - **dict**: Key-value pairs ({"name": "Alice", "age": 25})
#
# **6. Set Types:**
#
# - **set**: Unordered collection of unique elements ({7, 8, 9})
#
# - **frozenset**: Immutable version of a set
#
# **7. Binary Types:**
#
# - **bytes**, **bytearray**,: Used for handling binary data
#
# **8. None Type:**
#
# - **NoneType**: Represents the absence of a value (None)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **1. Numeric Data Types:**
#
# Python has three main **numeric data types**, which are used to store different kinds of numbers:
#
# **1. Integer (int):**
#
# - Represents whole numbers (positive, negative, or zero).
#
# - Example: 10, -5, 1000
#
# - No decimal point.
#
# **2. Floating-Point (float):**
# - Represents numbers with decimal points.
#
# - Example: 3.14, -0.5, 2.0
#
# - Used for precise calculations.
#
# **3. Complex (complex):**
#
# - Represents numbers with real and imaginary parts.
#
# - Example: 2 + 3j, -1.5 + 4j
#
# - Used in scientific and engineering computations.

# %%
# examples
x,y,z=10,10.0,10+20j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# **common functions used in Numeric Data Types:**
#
# - int()
#
# - float()
#
# - complex()

# %%
# int()---->data into integer
n1=10.98
print(n1)
print(type(n1))
# Out:
# 10.98
# <class 'float'>

# %%
# let us convert the float into an integer
print(int(n1))
# Out:
# 10

# %%
# let us convert the float into  complex
print(complex(n1))
# Out:
# (10.98+0j)

# %%
# let us take an integer, convert int-->float, int--->complex
n2=15
print(float(n2))
print(complex(n2))
# Out:
# 15.0
# (15+0j)

# %%
# let us try with complex ---> int, float
# Note: mathematically, above conversion is invalid.

# %% [markdown]
# # **Input Function**
#
# - The input() function in Python is used to take user input while a program is running.
#
# - It pauses the execution and waits for the user to enter something, then stores that input as a string.
#
# **Prpoerties of Input Function:**
#
#
# - **Pauses Execution:** When **input()** is used, the program halts and waits for the user to provide input.
#
# - **Returns a String:** Regardless of what the user enters, the function always returns the input as a string.
#
# - **Requires Conversion for Numerical Input:** If you need numbers, you'll have to manually convert the input using **int()** or **float()**.
#
# - **Accepts an Optional Prompt:** You can provide a **message within input()** to guide users on what to enter.
#
# - **Handles Multiple Inputs:** Users can input multiple values at once, which can be **split** and processed.

# %%
# Input() Implementation
# let us write a program to get sum of two number

x1=16
x2=23
s=x1+x2
print(s)
# Out:
# 39

# %%
# now let us write above program using input()
x1=input()
x2=input()
s=x1+x2
print(x1)
print(x2)
print(s)
# Out:
# 10
# 20
# 10
# 20
# 1020

# %%
print(type(x1))
print(type(x2))
# Out:
# <class 'str'>
# <class 'str'>

# %%
# now let us convert data type
x1=int(input())
x2=int(input())
s=x1+x2
print(s)
# Out:
# 10
# 20
# 30

# %%
print(type(x1))
print(type(x2))
# Out:
# <class 'int'>
# <class 'int'>

# %%
# comments inside input function
x1=int(input("Enter first number"))
x2=int(input("Enter second number"))
s=x1+x2
print(s)
# Out:
# Enter first number10
# Enter second number11
# 21

# %%
# one more example
city1=str(input("Enter first city"))
city2=str(input("Enter second city"))
print(city1,city2)
# Out:
# Enter first cityhyderabad
# Enter second citysecunderabad
# hyderabad secunderabad

# %% [markdown]
# # **Print Function:**
#
# - The **print()** function in Python is used to display output on the screen.
#
# - It allows you to show **text, numbers, or variables** to the user.
#
# **Properties of print function:**
#
# - **Displays Output:** Prints text or values to the console.
#
# - **Accepts Multiple Arguments:** You can print multiple values separated by commas.
#
# - **Supports Formatting:** You can format output using f-strings or **.format()**.
#
# - **Adds a New Line by Default:** Each **print()** call starts on a new line unless modified.
#
# - **Allows Custom Separators:** You can change how items are separated using **sep** and **end** parameters.

# %%
# print() implementation
x=10
y=20
z=x+y
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
# printing multiple variables using single print()
print(x,y,z)
# Out:
# 10 20 30

# %%
# 'sep' operator ----> It allows to define separator
print(x,y,z,sep=",")
# Out:
# 10$20$30

# %%
# another separator
print(x,y,z,sep=":")
# Out:
# 10:20:30

# %%
# Let us try one more time
print(x,y,z,sep="_")
# Out:
# 10_20_30

# %%
print(x,y,z,sep=" innomatics ")
# Out:
# 10 innomatics 20 innomatics 30

# %%
# special case of 'sep' -----> printing using newline \n
print(x,y,z,sep="\n")
# Out:
# 10
# 20
# 30

# %%
# tab space as a separator ----> \t
print(x,y,z,sep="\t")
# Out:
# 10	20	30

# %%
# 'end' -----> operator
print(x)
print(y)
print(z)
# Out:
# 10
# 20
# 30

# %%
print(x,end=",")
print(y,end=",")
print(z)
# Out:
# 10,20,30

# %%
# let us modify something in above
print(x,end=",")
print(y,end=",")
print(z,end=".")
# Out:
# 10,20,30.

# %%
# format() ----> to customize the output in required format
print("{}+{}={}".format(x,y,z))
# Out:
# 10+20=30

# %%
# observe the change
print("{}+{}={}".format(y,x,z))
# Out:
# 20+10=30

# %%
# let us try once more time
name="upendra"
country="India"
print("I am {}, I am from {}".format(name,country))
# Out:
# I am upendra, I am from India

# %%
# adding comments (prompt) in print()
print("first number",x)
print("second muner",y)
print("sum",z)
# Out:
# first number 10
# second muner 20
# sum 30

# %%
# print() allows to add multiple prompts (comments)
print(x,y,z)
print("x=",x,"y=",y,"z=",z)
# Out:
# 10 20 30
# x= 10 y= 20 z= 30

# %% [markdown]
# #**Question:** Create a program that displays your name and complete mailing address formatted in the manner that you would usually see it on the outside of an envelope. Your program does not need to read any input from the user.

# %%
name="upendra"
hn="2-21/5"
street="kphb"
landmark="JNTU Metro"
city="Hyderabad"
state="Telangana"
pin=500012
print(name,hn,street,landmark,city,state,pin,sep="\n")
# Out:
# upendra
# 2-21/5
# kphb
# JNTU Metro
# Hyderabad
# Telangana
# 500012

# %% [markdown]
# #**Question2:** Write a program that asks the user to enter his or her name. The program should respond with a message that says hello to the user, using his or her name.

# %%
name=input("Enter your name")
print("Hello",name)
# Out:
# Enter your nameupendra
# Hello upendra

# %%
name=input("Enter your name")
print("hello {} !!".format(name))
# Out:
# Enter your nameUpendra
# hello Upendra !!

# %% [markdown]
# #**Question 3:** Write a program that asks the user to enter the width and length of a room. Once the values have been read, your program should compute and display the area of the room. The length and the width will be entered as floating point numbers. Include units in your prompt and output message; either feet or meters, depending on which unit you are more comfortable working with.

# %%
length=float(input("Enter length of room in feet"))
width=float(input("Enter width of room in feet"))
area=length*width
print("Area of room is {} square feet.".format(area))
# Out:
# Enter length of room in feet23.6
# Enter width of room in feet15.9
# Area of room is 375.24 square feet.

# %% [markdown]
# #**Question 4:** In many jurisdictions a small deposit is added to drink containers to encourage people to recycle them. In one particular jurisdiction, drink containers holding one liter or less have a $0.10 deposit, and drink containers holding more than one liter have a $0.25 deposit. Write a program that reads the number of containers of each size from the user. Your program should continue by computing and displaying the refund that will be received for returning those containers. Format the output so that it includes a dollar sign and always displays exactly two decimal places.

# %%
x=int(input("No of containers below one Lit"))
y=int(input("No of containers above one Lit"))
refund=x*0.1+y*0.25
print("if you return {} small containers and {} large containers, you get total refund of {}$.".format(x,y,refund))
# Out:
# No of containers below one Lit25
# No of containers above one Lit50
# if you return 25 small containers and 50 large containers, you get total refund of 15.0$.
